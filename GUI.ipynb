# %%
import tkinter as tk #tk is dishionry
from tkinter import BooleanVar
from tkinter import ttk
from tkinter.ttk import*
from tkinter import scrolledtext
from tkinter import messagebox

# %%
top=tk.Tk()#name of window  and close intaintly

top.mainloop()# using this not close intaintly

# %%
top=tk.Tk()
top.title('my application')# name of                                          pack =pack the th line
top.geometry('500x400')
b1=tk.Button(top,text='click me!!!',bg='yellow').grid(column=0,row=1)
e1=tk.Entry(top).grid(column=1,row=1)
t1=tk.Text(top).grid(column=2,row=2)
l1=tk.Label(top,text='welcome',font=('ariel bold',50)).grid(column=3,row=3)


#combo box
combo=Combobox(top)
combo['value']=[1,2,3,4, 'next']
combo.current(2)
combo.grid(column=0,row=0)

#check button
ch=BooleanVar()
ch.set(True)
cb=Checkbutton(top,text='done',var=ch,width=30).grid(column=0,row=0)

#scrolled text
st=scrolledtext.ScrolledText(top,width=40,height=10).grid(column=3,row=3)

top.mainloop()

# %%
#square of a number
top = tk.Tk()

top.title('square')
top.geometry('500x400')

a = tk.IntVar()

def square():
    num = a.get()
    sq = num * num
    result = tk.Label(top, text = 'square is %i' %sq).place(x = 120, y = 200)
    messagebox.showinfo("result", "square is %i" %sq)
    
l = tk.Label(top, text = 'INPUT').place(x = 20, y = 100)
e = tk.Entry(top, textvariable = a).place(x = 100, y = 100)
b = tk.Button(top, text = 'sumbit' , bg = 'orange',command = square).place(x = 50, y = 150)

top.mainloop()

# %%
#addition
top = tk.Tk()

top.title('addition')
top.geometry('500x400')

a = tk.IntVar()
c = tk.IntVar()

def addition():
    num1 = a.get()
    num2 = c.get()
    sum = num1 + num2
    result = tk.Label(top, text = 'addition is %i' %sum).place(x = 120, y = 200)
    messagebox.showinfo("result", "addition is %i" %sum)
    
l = tk.Label(top, text = 'INPUT1').place(x = 20, y = 100)
l1 = tk.Label(top, text = 'INPUT2').place(x = 20, y = 120)
e = tk.Entry(top, textvariable = a).place(x = 100, y = 100)
e1 = tk.Entry(top, textvariable = c).place(x = 100, y = 120)
b = tk.Button(top, text = 'submit' , bg = 'orange',command = addition).place(x = 50, y = 150)

top.mainloop()

# %%
#subtraction
top = tk.Tk()

top.title('subtraction')
top.geometry('500x400')

a = tk.IntVar()
c = tk.IntVar()

def subtraction():
    num1 = a.get()
    num2 = c.get()
    sub = num1 - num2
    result = tk.Label(top, text = 'subtraction is %i' %sub).place(x = 120, y = 200)
    messagebox.showinfo("result", "subtraction is %i" %sub)
    
l = tk.Label(top, text = 'INPUT1').place(x = 20, y = 100)
l1 = tk.Label(top, text = 'INPUT2').place(x = 20, y = 120)
e = tk.Entry(top, textvariable = a).place(x = 100, y = 100)
e1 = tk.Entry(top, textvariable = c).place(x = 100, y = 120)
b = tk.Button(top, text = 'submit' , bg = 'orange',command = subtraction).place(x = 50, y = 150)

top.mainloop()

# %%
#multiplication
top = tk.Tk()

top.title('multiplication')
top.geometry('500x400')

a = tk.IntVar()
c = tk.IntVar()

def multiplication():
    num1 = a.get()
    num2 = c.get()
    multi = num1 * num2
    result = tk.Label(top, text = 'multiplication is %i' %multi).place(x = 120, y = 200)
    messagebox.showinfo("result", "multiplication is %i" %multi)
    
l = tk.Label(top, text = 'INPUT1').place(x = 20, y = 100)
l1 = tk.Label(top, text = 'INPUT2').place(x = 20, y = 120)
e = tk.Entry(top, textvariable = a).place(x = 100, y = 100)
e1 = tk.Entry(top, textvariable = c).place(x = 100, y = 120)
b = tk.Button(top, text = 'submit' , bg = 'orange',command = multiplication).place(x = 50, y = 150)

top.mainloop()

# %%
#division
top = tk.Tk()

top.title('division')
top.geometry('500x400')

a = tk.IntVar()
c = tk.IntVar()

def division():
    num1 = a.get()
    num2 = c.get()
    div = num1 / num2
    result = tk.Label(top, text = 'division is %i' %div).place(x = 120, y = 200)
    messagebox.showinfo("result", "division is %i" %div)
    
l = tk.Label(top, text = 'INPUT1').place(x = 20, y = 100)
l1 = tk.Label(top, text = 'INPUT2').place(x = 20, y = 120)
e = tk.Entry(top, textvariable = a).place(x = 100, y = 100)
e1 = tk.Entry(top, textvariable = c).place(x = 100, y = 120)
b = tk.Button(top, text = 'submit' , bg = 'orange',command = division).place(x = 50, y = 150)

top.mainloop()

# %%
#create for addition ,sub,mult,div of 2 numbers
import tkinter as tk
from tkinter import StringVar,Button,Entry

top=tk.Tk()
top.title('calculator')

#define the stringVr for the display
display=StringVar()
display.set("0")

#create an Entry widget for the display
entry=Entry(top,textvariable=display,width=16,font=('arial',24),bd=8,insertwidth=2,justify='right')
entry.grid(row=0,column=0,columnspan=4)

#function to handle button click
def button_click(char):
    current=display.get()
    if current=='0':
        display.set(char)
    else:
        display.set(current + char)

#function to clear the display
def button_clear():
    display.set('0')

#function to evaluate the expression
def button_equal():
 try:
     result=str(eval(display.get()))
     display.set(result)
 except:
      display.set('Error')

#create buttons
button_7=Button(top,text='7',command=lambda: button_click('7'),width=5,height=2)
button_7.grid(row=1,column=0)
button_8=Button(top,text='8',command=lambda: button_click('8'),width=5,height=2)
button_8.grid(row=1,column=1)
button_9=Button(top,text='9',command=lambda: button_click('9'),width=5,height=2)
button_9.grid(row=1,column=2)

button_div=Button(top,text='division',command=lambda: button_click('/'),width=5,height=2)
button_div.grid(row=1,column=3)
button_4=Button(top,text='4',command=lambda: button_click('4'),width=5,height=2)
button_4.grid(row=2,column=0)
button_5=Button(top,text='5',command=lambda: button_click('5'),width=5,height=2)
button_5.grid(row=2,column=1)
button_6=Button(top,text='6',command=lambda: button_click('6'),width=5,height=2)
button_6.grid(row=2,column=2)

button_multi=Button(top,text='multi',command=lambda: button_click('*'),width=5,height=2)
button_multi.grid(row=2,column=3)
button_1=Button(top,text='1',command=lambda: button_click('1'),width=5,height=2)
button_1.grid(row=3,column=0)
button_2=Button(top,text='2',command=lambda: button_click('2'),width=5,height=2)
button_2.grid(row=3,column=1)
button_3=Button(top,text='3',command=lambda: button_click('3'),width=5,height=2)
button_3.grid(row=3,column=2)

button_sub=Button(top,text='Substract',command=lambda: button_click('-'),width=5,height=2)
button_sub.grid(row=3,column=3)
button_0=Button(top,text='0',command=lambda: button_click('0'),width=5,height=2)
button_0.grid(row=4,column=0)
button_dot=Button(top,text='.',command=lambda: button_click('.'),width=5,height=2)
button_dot.grid(row=4,column=1)
button_clear=Button(top,text='clear',command=button_clear,width=5,height=2)
button_clear.grid(row=4,column=2)

button_add=Button(top,text='ADD',command=lambda: button_click('+'),width=5,height=2)
button_add.grid(row=4,column=3)
button_equal=Button(top,text='=',command=button_equal,width=22,height=2)
button_equal.grid(row=5,column=0,columnspan=4)

top.mainloop()
